# %% [markdown]
# ![cg.jpg](https://raw.githubusercontent.com/jdanifalcon/FundamentosIA/main/logo/logo_cg.jpg)
#
#
# # Proyecto, Parte 1: Preprocesamiento de los datos de INEGI 2020 para Macuspana, Tabasco, México.
#
# #### @date 03/04/2024

# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Cargar datos socioeconómicos y geoespaciales
# Ruta del archivo CSV en Google Drive
ruta = '/content/drive/MyDrive/inegi/2020/ageb27_2020.csv'

# Lee el archivo CSV en un DataFrame de pandas
data = pd.read_csv(ruta)
data
# Out:
#        ENTIDAD  NOM_ENT  MUN                      NOM_MUN  LOC  \
# 0           27  Tabasco    0  Total de la entidad Tabasco    0
# 1           27  Tabasco    1                     Balancán    0
# 2           27  Tabasco    1                     Balancán    1
# 3           27  Tabasco    1                     Balancán    1
# 4           27  Tabasco    1                     Balancán    1
# ...        ...      ...  ...                          ...  ...
# 17781       27  Tabasco   17                    Tenosique    1
# 17782       27  Tabasco   17                    Tenosique    1
# 17783       27  Tabasco   17                    Tenosique    1
# 17784       27  Tabasco   17                    Tenosique    1
# 17785       27  Tabasco   17                    Tenosique    1
#
#                             NOM_LOC  AGEB  MZA   POBTOT   POBFEM  ...  \
# 0               Total de la entidad  0000    0  2402598  1228927  ...
# 1               Total del municipio  0000    0    58524    29282  ...
# 2      Total de la localidad urbana  0000    0    13944     7272  ...
# 3                 Total AGEB urbana  0401    0     1962     1017  ...
# 4                          Balancán  0401    1       54       32  ...
# ...                             ...   ...  ...      ...      ...  ...
# 17781      Tenosique de Pino Suárez  0596   18       15        *  ...
# 17782      Tenosique de Pino Suárez  0596   19        5        *  ...
# 17783      Tenosique de Pino Suárez  0596   20        8        *  ...
# 17784      Tenosique de Pino Suárez  0596   21        2        *  ...
# 17785      Tenosique de Pino Suárez  0596   22        0        0  ...
#
#       VPH_TELEF VPH_CEL VPH_INTER VPH_STVP VPH_SPMVPI VPH_CVJ VPH_SINRTV  \
# 0        118527  563390    228487   276817      66338   31004      54983
# 1          2960   12347      3499     7392        486     227       1907
# 2           625    3917      1534     2402        302     133        305
# 3           144     587       244      353         57      15         53
# 4             9      16        13       13          4       0          *
# ...         ...     ...       ...      ...        ...     ...        ...
# 17781         *       *         *        *          *       *          *
# 17782         *       *         *        *          *       *          *
# 17783         *       *         *        *          *       *          *
# 17784         *       *         *        *          *       *          *
# 17785         0       0         0        0          0       0          0
#
#       VPH_SINLTC VPH_SINCINT VPH_SINTIC
# 0          96508      404524      25731
# 1           3607       12387        993
# 2            271        2258         75
# 3             38         330         12
# 4              *           6          0
# ...          ...         ...        ...
# 17781          *           *          *
# 17782          *           *          *
# 17783          *           *          *
# 17784          *           *          *
# 17785          0           0          0
#
# [17786 rows x 230 columns]

# %%
# Filtrado
palabra_referencia = 'Total'

# Eliminar filas (referencia en la columna 'NOM_LOC')
data = data[~data['NOM_LOC'].str.contains(r'\b' + palabra_referencia + r'\b', case=False, na=False, regex=True)]
data
# Out:
#        ENTIDAD  NOM_ENT  MUN    NOM_MUN  LOC                   NOM_LOC  AGEB  \
# 4           27  Tabasco    1   Balancán    1                  Balancán  0401
# 5           27  Tabasco    1   Balancán    1                  Balancán  0401
# 6           27  Tabasco    1   Balancán    1                  Balancán  0401
# 7           27  Tabasco    1   Balancán    1                  Balancán  0401
# 8           27  Tabasco    1   Balancán    1                  Balancán  0401
# ...        ...      ...  ...        ...  ...                       ...   ...
# 17781       27  Tabasco   17  Tenosique    1  Tenosique de Pino Suárez  0596
# 17782       27  Tabasco   17  Tenosique    1  Tenosique de Pino Suárez  0596
# 17783       27  Tabasco   17  Tenosique    1  Tenosique de Pino Suárez  0596
# 17784       27  Tabasco   17  Tenosique    1  Tenosique de Pino Suárez  0596
# 17785       27  Tabasco   17  Tenosique    1  Tenosique de Pino Suárez  0596
#
#        MZA  POBTOT POBFEM  ... VPH_TELEF VPH_CEL VPH_INTER VPH_STVP  \
# 4        1      54     32  ...         9      16        13       13
# 5        2      44     24  ...         5      13         6       10
# 6        3      28     13  ...         5      10         7        6
# 7        4      44     24  ...         3      15         6       12
# 8        5     110     58  ...         9      31        16       25
# ...    ...     ...    ...  ...       ...     ...       ...      ...
# 17781   18      15      *  ...         *       *         *        *
# 17782   19       5      *  ...         *       *         *        *
# 17783   20       8      *  ...         *       *         *        *
# 17784   21       2      *  ...         *       *         *        *
# 17785   22       0      0  ...         0       0         0        0
#
#       VPH_SPMVPI VPH_CVJ VPH_SINRTV VPH_SINLTC VPH_SINCINT VPH_SINTIC
# 4              4       0          *          *           6          0
# 5              0       *          0          0           4          0
# 6              0       0          *          *           4          0
# 7              0       0          0          0           8          0
# 8              7       *          0          3          16          0
# ...          ...     ...        ...        ...         ...        ...
# 17781          *       *          *          *           *          *
# 17782          *       *          *          *           *          *
# 17783          *       *          *          *           *          *
# 17784          *       *          *          *           *          *
# 17785          0       0          0          0           0          0
#
# [17008 rows x 230 columns]

# %%
Macuspana = data.loc[data['NOM_MUN'] == 'Macuspana']
Macuspana
# Out:
#        ENTIDAD  NOM_ENT  MUN    NOM_MUN  LOC               NOM_LOC  AGEB  MZA  \
# 13912       27  Tabasco   12  Macuspana    1             Macuspana  0072    1
# 13913       27  Tabasco   12  Macuspana    1             Macuspana  0072    2
# 13914       27  Tabasco   12  Macuspana    1             Macuspana  0072    3
# 13915       27  Tabasco   12  Macuspana    1             Macuspana  0072    4
# 13916       27  Tabasco   12  Macuspana    1             Macuspana  0072    5
# ...        ...      ...  ...        ...  ...                   ...   ...  ...
# 14879       27  Tabasco   12  Macuspana   91  Pemex (Ciudad Pemex)  0759   28
# 14880       27  Tabasco   12  Macuspana   91  Pemex (Ciudad Pemex)  0759   29
# 14881       27  Tabasco   12  Macuspana   91  Pemex (Ciudad Pemex)  0759   30
# 14882       27  Tabasco   12  Macuspana   91  Pemex (Ciudad Pemex)  0759   31
# 14883       27  Tabasco   12  Macuspana   91  Pemex (Ciudad Pemex)  0759   32
#
#        POBTOT POBFEM  ... VPH_TELEF VPH_CEL VPH_INTER VPH_STVP VPH_SPMVPI  \
# 13912     319    181  ...        47      84        53       62         21
# 13913     369    192  ...        42     106        99       85         16
# 13914     445    230  ...        46     120        76       81         18
# 13915      73     40  ...        10      16        11       13          *
# 13916     691    359  ...        38     147        59       78         20
# ...       ...    ...  ...       ...     ...       ...      ...        ...
# 14879       0      0  ...         0       0         0        0          0
# 14880       0      0  ...         0       0         0        0          0
# 14881       0      0  ...         0       0         0        0          0
# 14882       0      0  ...         0       0         0        0          0
# 14883       0      0  ...         0       0         0        0          0
#
#       VPH_CVJ VPH_SINRTV VPH_SINLTC VPH_SINCINT VPH_SINTIC
# 13912      12          4          8          36          *
# 13913       6          *          7          16          0
# 13914      11          5          9          50          *
# 13915       *          0          *           6          0
# 13916       5         14         27         106          7
# ...       ...        ...        ...         ...        ...
# 14879       0          0          0           0          0
# 14880       0          0          0           0          0
# 14881       0          0          0           0          0
# 14882       0          0          0           0          0
# 14883       0          0          0           0          0
#
# [927 rows x 230 columns]

# %%
#Macuspana['P15YM_AN']
listaDeseada = ['POBTOT','PROM_OCUP','P3YM_HLI','PHOGJEF_F','P15YM_AN','GRAPROES','PSINDER','PEA','POB15_64','TVIVHAB','VPH_AGUAFV','VPH_NODREN','VPH_PISOTI']
N_Macuspana = Macuspana.loc[:, listaDeseada]

# %%
N_Macuspana
# Out:
#        POBTOT PROM_OCUP P3YM_HLI PHOGJEF_F P15YM_AN GRAPROES PSINDER  PEA  \
# 13912     319      3.39        *       131        7     11.5      70  144
# 13913     369      3.18        *       185        8    10.45      54  169
# 13914     445      3.37        0       144        3    11.75     138  239
# 13915      73      4.06        0        19        *    11.29       7   27
# 13916     691      3.88       10       221       24     9.29     164  322
# ...       ...       ...      ...       ...      ...      ...     ...  ...
# 14879       0      0.00        0         0        0     0.00       0    0
# 14880       0      0.00        0         0        0     0.00       0    0
# 14881       0      0.00        0         0        0     0.00       0    0
# 14882       0      0.00        0         0        0     0.00       0    0
# 14883       0      0.00        0         0        0     0.00       0    0
#
#       POB15_64 TVIVHAB VPH_AGUAFV VPH_NODREN VPH_PISOTI
# 13912      214      94          0          0          0
# 13913      253     116          0          *          0
# 13914      312     132          0          0          0
# 13915       47      18          0          0          0
# 13916      454     178          *          0          6
# ...        ...     ...        ...        ...        ...
# 14879        0       0          0          0          0
# 14880        0       0          0          0          0
# 14881        0       0          0          0          0
# 14882        0       0          0          0          0
# 14883        0       0          0          0          0
#
# [927 rows x 13 columns]

# %%
#Macuspana['P15YM_AN']
listaDeseada = ['ENTIDAD','MUN','LOC','AGEB','MZA']
NM_Macuspana = Macuspana.loc[:, listaDeseada]
NM_Macuspana
# Out:
#        ENTIDAD  MUN  LOC  AGEB  MZA
# 13912       27   12    1  0072    1
# 13913       27   12    1  0072    2
# 13914       27   12    1  0072    3
# 13915       27   12    1  0072    4
# 13916       27   12    1  0072    5
# ...        ...  ...  ...   ...  ...
# 14879       27   12   91  0759   28
# 14880       27   12   91  0759   29
# 14881       27   12   91  0759   30
# 14882       27   12   91  0759   31
# 14883       27   12   91  0759   32
#
# [927 rows x 5 columns]

# %%
NM_Macuspana['ENTIDAD']=NM_Macuspana['ENTIDAD'].astype(str).str.rjust(2, '0')
NM_Macuspana['MUN']=NM_Macuspana['MUN'].astype(str).str.rjust(3, '0')
NM_Macuspana['LOC']=NM_Macuspana['LOC'].astype(str).str.rjust(4, '0')
NM_Macuspana['AGEB']=NM_Macuspana['AGEB'].astype(str).str.rjust(4, '0')
NM_Macuspana['MZA']=NM_Macuspana['MZA'].astype(str).str.rjust(3, '0')
NM_Macuspana['Unidas'] = NM_Macuspana['ENTIDAD'].astype(str) + NM_Macuspana['MUN'].astype(str) + NM_Macuspana['LOC'].astype(str) + NM_Macuspana['AGEB'].astype(str) + NM_Macuspana['MZA'].astype(str)
print(NM_Macuspana['Unidas'])
# Out:
# 13912    2701200010072001
# 13913    2701200010072002
# 13914    2701200010072003
# 13915    2701200010072004
# 13916    2701200010072005
#                ...
# 14879    2701200910759028
# 14880    2701200910759029
# 14881    2701200910759030
# 14882    2701200910759031
# 14883    2701200910759032
# Name: Unidas, Length: 927, dtype: object

# %%
N_Macuspana['Unidas'] = NM_Macuspana['Unidas']
N_Macuspana
# Out:
#        POBTOT PROM_OCUP P3YM_HLI PHOGJEF_F P15YM_AN GRAPROES PSINDER  PEA  \
# 13912     319      3.39        *       131        7     11.5      70  144
# 13913     369      3.18        *       185        8    10.45      54  169
# 13914     445      3.37        0       144        3    11.75     138  239
# 13915      73      4.06        0        19        *    11.29       7   27
# 13916     691      3.88       10       221       24     9.29     164  322
# ...       ...       ...      ...       ...      ...      ...     ...  ...
# 14879       0      0.00        0         0        0     0.00       0    0
# 14880       0      0.00        0         0        0     0.00       0    0
# 14881       0      0.00        0         0        0     0.00       0    0
# 14882       0      0.00        0         0        0     0.00       0    0
# 14883       0      0.00        0         0        0     0.00       0    0
#
#       POB15_64 TVIVHAB VPH_AGUAFV VPH_NODREN VPH_PISOTI            Unidas
# 13912      214      94          0          0          0  2701200010072001
# 13913      253     116          0          *          0  2701200010072002
# 13914      312     132          0          0          0  2701200010072003
# 13915       47      18          0          0          0  2701200010072004
# 13916      454     178          *          0          6  2701200010072005
# ...        ...     ...        ...        ...        ...               ...
# 14879        0       0          0          0          0  2701200910759028
# 14880        0       0          0          0          0  2701200910759029
# 14881        0       0          0          0          0  2701200910759030
# 14882        0       0          0          0          0  2701200910759031
# 14883        0       0          0          0          0  2701200910759032
#
# [927 rows x 14 columns]

# %%
N_Macuspana= N_Macuspana[['Unidas','POBTOT','PROM_OCUP','P3YM_HLI','PHOGJEF_F','P15YM_AN','GRAPROES','PSINDER','PEA','POB15_64','TVIVHAB','VPH_AGUAFV','VPH_NODREN','VPH_PISOTI']]
N_Macuspana
# Out:
#                  Unidas  POBTOT PROM_OCUP P3YM_HLI PHOGJEF_F P15YM_AN  \
# 13912  2701200010072001     319      3.39        *       131        7
# 13913  2701200010072002     369      3.18        *       185        8
# 13914  2701200010072003     445      3.37        0       144        3
# 13915  2701200010072004      73      4.06        0        19        *
# 13916  2701200010072005     691      3.88       10       221       24
# ...                 ...     ...       ...      ...       ...      ...
# 14879  2701200910759028       0      0.00        0         0        0
# 14880  2701200910759029       0      0.00        0         0        0
# 14881  2701200910759030       0      0.00        0         0        0
# 14882  2701200910759031       0      0.00        0         0        0
# 14883  2701200910759032       0      0.00        0         0        0
#
#       GRAPROES PSINDER  PEA POB15_64 TVIVHAB VPH_AGUAFV VPH_NODREN VPH_PISOTI
# 13912     11.5      70  144      214      94          0          0          0
# 13913    10.45      54  169      253     116          0          *          0
# 13914    11.75     138  239      312     132          0          0          0
# 13915    11.29       7   27       47      18          0          0          0
# 13916     9.29     164  322      454     178          *          0          6
# ...        ...     ...  ...      ...     ...        ...        ...        ...
# 14879     0.00       0    0        0       0          0          0          0
# 14880     0.00       0    0        0       0          0          0          0
# 14881     0.00       0    0        0       0          0          0          0
# 14882     0.00       0    0        0       0          0          0          0
# 14883     0.00       0    0        0       0          0          0          0
#
# [927 rows x 14 columns]

# %%
# Ruta completa en Google Drive
ruta_google_drive = '/content/drive/MyDrive/inegi/macuspana/N_macuspana.csv'

# Guardar el DataFrame como un archivo CSV en Google Drive
N_Macuspana.to_csv(ruta_google_drive, index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-dec423fb535b> in <cell line: 5>()
#       3
#       4 # Guardar el DataFrame como un archivo CSV en Google Drive
# ----> 5 N_Macuspana.to_csv(ruta_google_drive, index=False)
#
# NameError: name 'N_Macuspana' is not defined

# %%
N_Macuspana['TVIVHAB'].max()
# Out:
# '97'
